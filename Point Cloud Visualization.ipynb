# %%
import pptk

# %%
import pandas as pd

# %%
py_pc= pd.read_csv('C:/AirSim/test/NH/1557230417412320900.csv', sep=",")
py_pc
# Out:
#                x           y          z                   labels
# 0      54.850044  132.673492 -17.477800  InstancedFoliageActor_0
# 1     -15.903365  129.515900  -5.882791     Roof_Middle_Apex_116
# 2     -15.963632  129.842529  -5.911294     Roof_Middle_Apex_116
# 3     -16.189989  130.041245  -5.903306     Roof_Middle_Apex_116
# 4     -16.659788  130.041245  -5.840305     Roof_Middle_Apex_116
# 5     -17.773445  129.499084  -5.629010     Roof_Middle_Apex_116
# 6     -17.714622  129.915253  -5.685850     Roof_Middle_Apex_116
# 7     -17.653767  130.341476  -5.744651     Roof_Middle_Apex_116
# 8     -17.590790  130.778244  -5.805501     Roof_Middle_Apex_116
# 9     -17.525602  131.226074  -5.868489     Roof_Middle_Apex_116
# 10    -17.458094  131.685501  -5.933718     Roof_Middle_Apex_116
# 11    -17.388163  132.157104  -6.001287     Roof_Middle_Apex_116
# 12    -17.315693  132.641495  -6.071310     Roof_Middle_Apex_116
# ...

# %%
newdf = py_pc[['x','y','z']]
newdf
# Out:
#                x           y          z
# 0      54.850044  132.673492 -17.477800
# 1     -15.903365  129.515900  -5.882791
# 2     -15.963632  129.842529  -5.911294
# 3     -16.189989  130.041245  -5.903306
# 4     -16.659788  130.041245  -5.840305
# 5     -17.773445  129.499084  -5.629010
# 6     -17.714622  129.915253  -5.685850
# 7     -17.653767  130.341476  -5.744651
# 8     -17.590790  130.778244  -5.805501
# 9     -17.525602  131.226074  -5.868489
# 10    -17.458094  131.685501  -5.933718
# 11    -17.388163  132.157104  -6.001287
# 12    -17.315693  132.641495  -6.071310
# 13    -21.132717  129.353500  -5.181511
# 14    -21.289799  129.555344  -5.188219
# 15    -21.333832  129.872543  -5.224030
# 16    -21.712473  129.849686  -5.175666
# 17    -22.061670  129.849686  -5.134270
# 18    -22.404280  129.849686  -5.094094
# 19    -22.740543  129.849686  -5.055101
# 20    -23.070724  129.849686  -5.017245
# 21    -23.395006  129.849701  -4.980494
# ...

# %%
vpy = pptk.viewer(newdf)

# %%
vpy
